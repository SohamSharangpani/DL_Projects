# %%
#Importing keras libraries and packages

from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import MaxPooling2D

#step1 Initializing CNN
classifier = Sequential()

# step2 adding 1st Convolution layer and Pooling layer
classifier.add(Convolution2D(32,(3,3),input_shape = (64,64,3), activation = 'relu'))

classifier.add(MaxPooling2D(pool_size = (2, 2)))

# step3 adding 2nd convolution layer and polling layer
classifier.add(Convolution2D(32,(3,3), activation = 'relu'))

classifier.add(MaxPooling2D(pool_size = (2, 2)))


#step4 Flattening the layers
classifier.add(Flatten())

#step5 Full_Connection

classifier.add(Dense(units=32,activation = 'relu'))

classifier.add(Dense(units=64,activation = 'relu'))

classifier.add(Dense(units=128,activation = 'relu'))

classifier.add(Dense(units=256,activation = 'relu'))

classifier.add(Dense(units=256,activation = 'relu'))

classifier.add(Dense(units=6,activation = 'softmax'))

#step6 Compiling CNN
classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

#step7 Fitting CNN to images

from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255, # To rescaling the image in range of [0,1]
                                   shear_range = 0.2, # To randomly shear the images 
                                   zoom_range = 0.2, # To randomly zoom the images
                                   horizontal_flip = True) #  for randomly flipping half of the images horizontally 

test_datagen = ImageDataGenerator(rescale = 1./255)
print("\nTraining the data...\n")
training_set = train_datagen.flow_from_directory('train',
                                                target_size=(64,64),
                                                batch_size=12, #Total no. of batches
                                                class_mode='categorical')

test_set = test_datagen.flow_from_directory('test',
                                            target_size=(64,64),
                                            batch_size=12,
                                            class_mode='categorical')

classifier.fit_generator(training_set,
                         epochs = 50,
                         verbose = 2,
                         validation_data = test_set) # Total testing images

#step8 saving model 

classifier.save("model.h5")
# Out:
# Training the data...
#
# Found 1212 images belonging to 6 classes.
# Found 300 images belonging to 6 classes.
# Epoch 1/50
# 101/101 - 24s - loss: 1.6011 - accuracy: 0.3111 - val_loss: 1.2884 - val_accuracy: 0.4133
# Epoch 2/50
# 101/101 - 17s - loss: 1.2994 - accuracy: 0.4175 - val_loss: 1.1572 - val_accuracy: 0.5167
# Epoch 3/50
# 101/101 - 17s - loss: 1.1613 - accuracy: 0.5248 - val_loss: 0.9883 - val_accuracy: 0.6067
# Epoch 4/50
# 101/101 - 17s - loss: 0.9633 - accuracy: 0.5990 - val_loss: 0.7420 - val_accuracy: 0.6933
# Epoch 5/50
# 101/101 - 17s - loss: 0.7964 - accuracy: 0.7038 - val_loss: 0.6523 - val_accuracy: 0.7100
# Epoch 6/50
# 101/101 - 17s - loss: 0.6661 - accuracy: 0.7583 - val_loss: 0.7641 - val_accuracy: 0.7033
# Epoch 7/50
# 101/101 - 16s - loss: 0.6115 - accuracy: 0.7863 - val_loss: 0.5699 - val_accuracy: 0.7600
# Epoch 8/50
# 101/101 - 17s - loss: 0.5650 - accuracy: 0.8036 - val_loss: 0.5837 - val_accuracy: 0.7933
# Epoch 9/50
# 101/101 - 16s - loss: 0.4928 - accuracy: 0.8243 - val_loss: 0.4758 - val_accuracy: 0.8267
# Epoch 10/50
# 101/101 - 17s - loss: 0.4422 - accuracy: 0.8523 - val_loss: 0.4038 - val_accuracy: 0.8533
# Epoch 11/50
# 101/101 - 18s - loss: 0.4832 - accuracy: 0.8325 - val_loss: 0.3162 - val_accuracy: 0.9000
# Epoch 12/50
# 101/101 - 18s - loss: 0.3949 - accuracy: 0.8672 - val_loss: 0.3050 - val_accuracy: 0.8967
# Epoch 13/50
# 101/101 - 17s - loss: 0.3607 - accuracy: 0.8738 - val_loss: 0.3624 - val_accuracy: 0.8633
# Epoch 14/50
# 101/101 - 18s - loss: 0.3207 - accuracy: 0.8853 - val_loss: 0.5004 - val_accuracy: 0.8333
# Epoch 15/50
# 101/101 - 18s - loss: 0.4138 - accuracy: 0.8589 - val_loss: 0.3640 - val_accuracy: 0.8667
# Epoch 16/50
# 101/101 - 17s - loss: 0.3023 - accuracy: 0.8952 - val_loss: 0.3311 - val_accuracy: 0.8767
# Epoch 17/50
# 101/101 - 17s - loss: 0.3276 - accuracy: 0.8878 - val_loss: 0.4280 - val_accuracy: 0.8667
# Epoch 18/50
# 101/101 - 17s - loss: 0.2987 - accuracy: 0.8985 - val_loss: 0.2831 - val_accuracy: 0.9100
# Epoch 19/50
# 101/101 - 17s - loss: 0.2652 - accuracy: 0.8969 - val_loss: 0.3307 - val_accuracy: 0.8900
# Epoch 20/50
# 101/101 - 17s - loss: 0.2678 - accuracy: 0.9051 - val_loss: 0.2742 - val_accuracy: 0.9000
# Epoch 21/50
# 101/101 - 17s - loss: 0.2419 - accuracy: 0.9158 - val_loss: 0.2701 - val_accuracy: 0.9133
# Epoch 22/50
# 101/101 - 17s - loss: 0.2365 - accuracy: 0.9241 - val_loss: 0.2375 - val_accuracy: 0.8967
# Epoch 23/50
# 101/101 - 18s - loss: 0.2052 - accuracy: 0.9224 - val_loss: 0.3353 - val_accuracy: 0.8867
# Epoch 24/50
# 101/101 - 17s - loss: 0.2417 - accuracy: 0.9175 - val_loss: 0.3379 - val_accuracy: 0.8833
# Epoch 25/50
# 101/101 - 17s - loss: 0.2502 - accuracy: 0.9068 - val_loss: 0.3210 - val_accuracy: 0.8933
# Epoch 26/50
# 101/101 - 17s - loss: 0.2370 - accuracy: 0.9257 - val_loss: 0.3772 - val_accuracy: 0.8633
# Epoch 27/50
# 101/101 - 18s - loss: 0.2029 - accuracy: 0.9315 - val_loss: 0.4486 - val_accuracy: 0.8600
# Epoch 28/50
# 101/101 - 18s - loss: 0.2007 - accuracy: 0.9200 - val_loss: 0.4091 - val_accuracy: 0.8400
# Epoch 29/50

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\soham\anaconda3\lib\site-packages (2.3.1)
# Requirement already satisfied: wrapt>=1.11.1 in c:\users\soham\anaconda3\lib\site-packages (from tensorflow) (1.11.2)
# Requirement already satisfied: absl-py>=0.7.0 in c:\users\soham\anaconda3\lib\site-packages (from tensorflow) (0.10.0)
# Requirement already satisfied: numpy<1.19.0,>=1.16.0 in c:\users\soham\anaconda3\lib\site-packages (from tensorflow) (1.18.5)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\soham\anaconda3\lib\site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: grpcio>=1.8.6 in c:\users\soham\anaconda3\lib\site-packages (from tensorflow) (1.33.1)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in c:\users\soham\anaconda3\lib\site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: wheel>=0.26 in c:\users\soham\anaconda3\lib\site-packages (from tensorflow) (0.34.2)
# Requirement already satisfied: google-pasta>=0.1.8 in c:\users\soham\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\soham\anaconda3\lib\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in c:\users\soham\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\soham\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in c:\users\soham\anaconda3\lib\site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\soham\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: gast==0.3.3 in c:\users\soham\anaconda3\lib\site-packages (from tensorflow) (0.3.3)
# Requirement already satisfied: astunparse==1.6.3 in c:\users\soham\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in c:\users\soham\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: setuptools in c:\users\soham\anaconda3\lib\site-packages (from protobuf>=3.9.2->tensorflow) (49.2.0.post20200714)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\soham\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (3.3.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\soham\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (2.24.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\soham\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (1.7.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\soham\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (0.4.1)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\soham\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (1.0.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\soham\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (1.22.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\soham\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\soham\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\soham\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\soham\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (3.0.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\soham\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\soham\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\soham\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (4.1.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.5" in c:\users\soham\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (4.6)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\soham\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\soham\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (0.4.8)
